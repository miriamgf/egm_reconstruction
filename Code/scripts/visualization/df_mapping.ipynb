# %%
import numpy as np
import scipy.io as sio
import vtk
from scipy.interpolate import interp1d
from vtk.util.numpy_support import numpy_to_vtk

import os
import cv2
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../..", "Code")))
from scipy.stats import pearsonr, spearmanr
import matplotlib.pyplot as plt
import pandas as pd
from tools_ import freq_phase_analysis as freq_pha

# Assuming EGMRenderer is defined in the same directory as this notebook
from utils.renderizer import EGMRenderer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 17
#      14 from tools_ import freq_phase_analysis as freq_pha
#      16 # Assuming EGMRenderer is defined in the same directory as this notebook
# ---> 17 from utils.renderizer import EGMRenderer
#
# ImportError: cannot import name 'EGMRenderer' from 'utils.renderizer' (/home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/scripts/visualization/utils/renderizer.py)

# %%
model_path="/home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/output/experiments/experiments_VAE/OMAMI_VAE_ski_bs_400_2048_norm/reconstructions_by_model_OMAMI_VAE_ski_bs_400_2048_norm.mat"

csv_corr="/home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/output/experiments/experiments_VAE/OMAMI_VAE_bs_400_2048_norm/corr_df_test.csv"
df = pd.read_csv(csv_corr)
df_sorted = df.sort_values(by='mean correlation', ascending=False)
df_sorted

df_sorted.head(20)
# Out:
#                             name  mean correlation
# 11  Simulation_01_200212_001_  5          0.469409
# 2   Simulation_01_200316_001_  3          0.465450
# 3   Simulation_01_200316_001_  4          0.128306
# 5   Simulation_01_200316_001_  8          0.115964
# 6   Simulation_01_200428_001_004          0.090596
# 8   Simulation_01_200428_001_010          0.090585
# 7   Simulation_01_200212_001_ 10          0.073930
# 10  Simulation_01_200428_001_008          0.043998
# 4   Simulation_01_210208_001_002          0.009765
# 0             LA_RSPV_CAF_150115          0.005690
# 9             LA_PLAW_140711_arm          0.003116
# 1   Simulation_01_210119_001_001          0.000671

# %%
def corr_spearman_cols(array1, array2):
    """
    Calcula la correlación de Spearman entre las columnas de dos arrays.

    Args:
        array1: un array de numpy de dimensión (n,m)
        array2: otro array de numpy de dimensión (n,m)

    Returns:
        Un array de numpy de dimensión (m,) que contiene la correlación de Spearman
        de las columnas de array1 y array2.
    """

    # Verificar si ambos arrays tienen las mismas dimensiones
    assert (
        array1.shape == array2.shape
    ), "Los arrays deben tener las mismas dimensiones."

    # Calcular la correlación de Spearman de las columnas de ambos arrays
    n_cols = array1.shape[1]
    corr = np.zeros(n_cols)
    for i in range(n_cols):
        corr[i], _ = spearmanr(array1[:, i], array2[:, i])

    return corr

# %%
# Cargar datos
#model_path = "/home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/output/experiments/experiments_VAE/OMAMI_weighted/reconstructions_by_model_OMAMI_weighted.mat"
model_path="/home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/output/experiments/experiments_VAE/pruebas interpol/reconstructions_by_model_pruebas interpol.mat"
model_path="/home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/output/experiments/experiments_VAE/OMAMI_VAE_bs_400_2048_norm/reconstructions_by_model_OMAMI_VAE_bs_400_2048_norm.mat"
geom_path_CF = "/home/pdi/miriamgf/tesis/Autoencoders/geometries/Atria_geom/Modelos_computacionales_Carlos_Fambuena/Atria.mat"
geom_path_edgar= "/home/pdi/miriamgf/tesis/Autoencoders/geometries/Atria_geom/Modelos_Edgar/Atria.mat"
model_path_database= "/home/pdi/miriamgf/tesis/Autoencoders/Data/modelLA_RSPV_CAF_150115/EGMs.mat"
output_directory = "/home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/output/renderized_heart/OMAMI_bs_200"
path_tikhonov="/home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/scripts/Tikhonov/figures/tikhonov_matlab.mat"
os.makedirs(output_directory, exist_ok=True)

tikhonov = False

# Cargar datos del modelo y la geometría
model_name="modelSimulation_01_200316_001_  4" 
try:
    model = sio.loadmat(model_path)[model_name]
    print('Loaded model ', model_name)
except:
    model = sio.loadmat(model_path)

try:
    geom = sio.loadmat(geom_path_CF)["geometries"]
except:
    geom = sio.loadmat(geom_path_CF)
# Out:
# Loaded model  modelSimulation_01_200316_001_  4

# %%
# Extraer datos
y_reconstructed = model["reconstruction"][0,0]
y_label = model["label"][0,0]
heart = geom["heart"]
faces = heart["faces"][0, 0] - 1  # Convertir a índice base 0
vertices = heart["vertices"][0, 0]

# %%
y_reconstructed, sig_k_rec, phase_rec = freq_pha.kuklik_DF_phase(y_reconstructed.T, fs=200)
y_label, sig_k_rec, phase_rec = freq_pha.kuklik_DF_phase(y_label.T, fs=200)
# Out:
# /home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/tools_/freq_phase_analysis.py:121: RuntimeWarning: divide by zero encountered in divide
#   invf = np.divide(1, f)
# Kuklik signal recomposition. Node: 0
# Kuklik signal recomposition. Node: 1
# Kuklik signal recomposition. Node: 2
# Kuklik signal recomposition. Node: 3
# Kuklik signal recomposition. Node: 4
# Kuklik signal recomposition. Node: 5
# Kuklik signal recomposition. Node: 6
# Kuklik signal recomposition. Node: 7
# Kuklik signal recomposition. Node: 8
# Kuklik signal recomposition. Node: 9
# Kuklik signal recomposition. Node: 10
# Kuklik signal recomposition. Node: 11
# Kuklik signal recomposition. Node: 12
# Kuklik signal recomposition. Node: 13
# Kuklik signal recomposition. Node: 14
# Kuklik signal recomposition. Node: 15
# Kuklik signal recomposition. Node: 16
# Kuklik signal recomposition. Node: 17
# Kuklik signal recomposition. Node: 18
# Kuklik signal recomposition. Node: 19
# Kuklik signal recomposition. Node: 20
# Kuklik signal recomposition. Node: 21
# Kuklik signal recomposition. Node: 22
# Kuklik signal recomposition. Node: 23
# Kuklik signal recomposition. Node: 24
# Kuklik signal recomposition. Node: 25
# Kuklik signal recomposition. Node: 26
# Kuklik signal recomposition. Node: 27
# Kuklik signal recomposition. Node: 28
# Kuklik signal recomposition. Node: 29
# Kuklik signal recomposition. Node: 30
# Kuklik signal recomposition. Node: 31
# Kuklik signal recomposition. Node: 32
# Kuklik signal recomposition. Node: 1000
# Kuklik signal recomposition. Node: 1001
# Kuklik signal recomposition. Node: 1002
# Kuklik signal recomposition. Node: 1003
# Kuklik signal recomposition. Node: 1004
# Kuklik signal recomposition. Node: 1005
# Kuklik signal recomposition. Node: 1006
# Kuklik signal recomposition. Node: 1007
# Kuklik signal recomposition. Node: 1008
# Kuklik signal recomposition. Node: 1009
# Kuklik signal recomposition. Node: 1010
# Kuklik signal recomposition. Node: 1011
# Kuklik signal recomposition. Node: 1012
# Kuklik signal recomposition. Node: 1013
# Kuklik signal recomposition. Node: 1014
# Kuklik signal recomposition. Node: 1015
# Kuklik signal recomposition. Node: 1016
# Kuklik signal recomposition. Node: 1017
# Kuklik signal recomposition. Node: 1018
# Kuklik signal recomposition. Node: 1019
# Kuklik signal recomposition. Node: 1020
# Kuklik signal recomposition. Node: 1021
# Kuklik signal recomposition. Node: 1022
# Kuklik signal recomposition. Node: 1023
# Kuklik signal recomposition. Node: 1024
# Kuklik signal recomposition. Node: 1025
# Kuklik signal recomposition. Node: 1026
# Kuklik signal recomposition. Node: 1027
# Kuklik signal recomposition. Node: 1028
# Kuklik signal recomposition. Node: 1029
# Kuklik signal recomposition. Node: 1030
# Kuklik signal recomposition. Node: 1031
# Kuklik signal recomposition. Node: 1032
# Kuklik signal recomposition. Node: 1033
# Kuklik signal recomposition. Node: 1034
# Kuklik signal recomposition. Node: 1035
# Kuklik signal recomposition. Node: 1036
# Kuklik signal recomposition. Node: 1037
# Kuklik signal recomposition. Node: 1038
# Kuklik signal recomposition. Node: 1039
# Kuklik signal recomposition. Node: 1040
# Kuklik signal recomposition. Node: 1041
# Kuklik signal recomposition. Node: 1042
# Kuklik signal recomposition. Node: 1043
# Kuklik signal recomposition. Node: 1044
# Kuklik signal recomposition. Node: 1045
# Kuklik signal recomposition. Node: 1046
# Kuklik signal recomposition. Node: 1047
# Kuklik signal recomposition. Node: 1048
# Kuklik signal recomposition. Node: 1049
# Kuklik signal recomposition. Node: 1050
# Kuklik signal recomposition. Node: 1051
# Kuklik signal recomposition. Node: 1052
# Kuklik signal recomposition. Node: 1053
# Kuklik signal recomposition. Node: 1054
# Kuklik signal recomposition. Node: 1055
# Kuklik signal recomposition. Node: 1056
# Kuklik signal recomposition. Node: 1057
# Kuklik signal recomposition. Node: 1058
# Kuklik signal recomposition. Node: 1059
# Kuklik signal recomposition. Node: 1060
# Kuklik signal recomposition. Node: 1061
# Kuklik signal recomposition. Node: 1062
# Kuklik signal recomposition. Node: 1063
# Kuklik signal recomposition. Node: 1064
# Kuklik signal recomposition. Node: 1065
# Kuklik signal recomposition. Node: 1066
# Kuklik signal recomposition. Node: 1067
# Kuklik signal recomposition. Node: 1068
# Kuklik signal recomposition. Node: 1069
# Kuklik signal recomposition. Node: 1070
# Kuklik signal recomposition. Node: 1071
# Kuklik signal recomposition. Node: 1072
# Kuklik signal recomposition. Node: 1073
# Kuklik signal recomposition. Node: 1074
# Kuklik signal recomposition. Node: 1075
# Kuklik signal recomposition. Node: 1076
# Kuklik signal recomposition. Node: 1154
# Kuklik signal recomposition. Node: 1155
# Kuklik signal recomposition. Node: 1156
# Kuklik signal recomposition. Node: 1157
# Kuklik signal recomposition. Node: 1158
# Kuklik signal recomposition. Node: 1159
# Kuklik signal recomposition. Node: 1160
# Kuklik signal recomposition. Node: 1161
# Kuklik signal recomposition. Node: 1162
# Kuklik signal recomposition. Node: 1163
# Kuklik signal recomposition. Node: 1164
# Kuklik signal recomposition. Node: 1165
# Kuklik signal recomposition. Node: 1166
# Kuklik signal recomposition. Node: 1167
# Kuklik signal recomposition. Node: 1168
# Kuklik signal recomposition. Node: 1169
# Kuklik signal recomposition. Node: 1170
# Kuklik signal recomposition. Node: 1171
# Kuklik signal recomposition. Node: 1172
# Kuklik signal recomposition. Node: 1173
# Kuklik signal recomposition. Node: 1174
# Kuklik signal recomposition. Node: 1175
# Kuklik signal recomposition. Node: 1176
# Kuklik signal recomposition. Node: 1177
# Kuklik signal recomposition. Node: 1178
# Kuklik signal recomposition. Node: 1179
# Kuklik signal recomposition. Node: 1180
# Kuklik signal recomposition. Node: 1181
# Kuklik signal recomposition. Node: 1182
# Kuklik signal recomposition. Node: 1183
# Kuklik signal recomposition. Node: 1184
# Kuklik signal recomposition. Node: 1185
# Kuklik signal recomposition. Node: 1186
# Kuklik signal recomposition. Node: 1187
# Kuklik signal recomposition. Node: 1188
# Kuklik signal recomposition. Node: 1189
# Kuklik signal recomposition. Node: 1190
# Kuklik signal recomposition. Node: 1191
# Kuklik signal recomposition. Node: 1192
# Kuklik signal recomposition. Node: 1193
# Kuklik signal recomposition. Node: 1194
# Kuklik signal recomposition. Node: 1195
# Kuklik signal recomposition. Node: 1196
# Kuklik signal recomposition. Node: 1197
# Kuklik signal recomposition. Node: 1198
# Kuklik signal recomposition. Node: 1199
# Kuklik signal recomposition. Node: 1200
# Kuklik signal recomposition. Node: 1201
# Kuklik signal recomposition. Node: 1202
# Kuklik signal recomposition. Node: 1203
# Kuklik signal recomposition. Node: 1204
# Kuklik signal recomposition. Node: 1205
# Kuklik signal recomposition. Node: 1206
# Kuklik signal recomposition. Node: 1207
# Kuklik signal recomposition. Node: 1208
# Kuklik signal recomposition. Node: 1209
# Kuklik signal recomposition. Node: 1210
# Kuklik signal recomposition. Node: 1211
# Kuklik signal recomposition. Node: 1212
# Kuklik signal recomposition. Node: 1213
# Kuklik signal recomposition. Node: 1214
# Kuklik signal recomposition. Node: 1215
# Kuklik signal recomposition. Node: 1216
# Kuklik signal recomposition. Node: 1217
# Kuklik signal recomposition. Node: 1218
# Kuklik signal recomposition. Node: 1219
# Kuklik signal recomposition. Node: 1220
# Kuklik signal recomposition. Node: 1221
# Kuklik signal recomposition. Node: 1222
# ...
# Kuklik signal recomposition. Node: 1648
# Kuklik signal recomposition. Node: 1649
# Kuklik signal recomposition. Node: 1650
# Kuklik signal recomposition. Node: 1651
# Kuklik signal recomposition. Node: 1652
# Kuklik signal recomposition. Node: 1653
# Kuklik signal recomposition. Node: 1654
# Kuklik signal recomposition. Node: 2038
# Kuklik signal recomposition. Node: 2039
# Kuklik signal recomposition. Node: 2040
# Kuklik signal recomposition. Node: 2041
# Kuklik signal recomposition. Node: 2042
# Kuklik signal recomposition. Node: 2043
# Kuklik signal recomposition. Node: 2044
# Kuklik signal recomposition. Node: 2045
# Kuklik signal recomposition. Node: 2046
# Kuklik signal recomposition. Node: 2047

# %%
y_reconstructed=y_reconstructed.T
y_label=y_label.T

# %%
def create_custom_colormap():
    # Crear una tabla de colores
    lookup_table = vtk.vtkLookupTable()
    lookup_table.SetNumberOfTableValues(256)  # Número de colores en la tabla
    lookup_table.SetRange(min_val_value, max_val_value)  # Rango de valores para la interpolación
    lookup_table.Build()

    # Configurar la interpolación de colores (azul -> rojo)
    for i in range(256):
        t = i / 255.0  # Normalizar entre 0 y 1
        if t < 0.5:
            # De azul (t=0) a blanco (t=0.5)
            r = t * 2  # Rojo aumenta
            g = t * 2  # Verde aumenta
            b = 1.0    # Azul se mantiene máximo
        else:
            # De blanco (t=0.5) a rojo (t=1)
            r = 1.0    # Rojo se mantiene máximo
            g = 2 * (1 - t)  # Verde disminuye
            b = 2 * (1 - t)  # Azul disminuye
        lookup_table.SetTableValue(i, r, g, b, 1.0)  # Último valor es la opacidad


    return lookup_table

# %%
max_val_value=np.max(y_reconstructed)
min_val_value=np.min(y_reconstructed)
print(min_val_value)
# Out:
# 8.0

# %%
max_val_value=np.max(y_reconstructed)
min_val_value=np.min(y_reconstructed)
# Crear renderizadores para var_represent y var_represent_original
renderer_var = EGMRenderer(faces, vertices, min_val=min_val_value, max_val=max_val_value)
try:
    renderer_label = EGMRenderer(faces, vertices,  min_val=min_val_value, max_val=max_val_value)
except:
    y_label = y_label[0][0]
    renderer_label = EGMRenderer(faces, vertices, min_val=min_val_value, max_val=max_val_value)

# Estándar y normalización de los datos (sin cambios)

estandarizar = False
normalizar = False

if estandarizar:
    y_label_std = np.zeros_like(y_label)
    for nodo in range(y_label.shape[1]): 
        mean_val = np.mean(y_label[:, nodo])  
        std_val = np.std(y_label[:, nodo])    
        if std_val != 0:  
            y_label_std[:, nodo] = (y_label[:, nodo] - mean_val) / std_val
        else:
            y_label_std[:, nodo] = 0  
    var_represent = y_reconstructed
    var_represent_original = y_label_std

if normalizar:
    y_label_n = np.zeros_like(y_label)
    for nodo in range(y_label.shape[1]):  
        min_val = np.min(y_label[:, nodo])
        max_val = np.max(y_label[:, nodo])
        
        if max_val != min_val:  
            y_label_n[:, nodo] = (y_label[:, nodo] - min_val) / (max_val - min_val)
        else:
            y_label_n[:, nodo] = 0  

    var_represent = y_reconstructed
    var_represent_original = y_label_n

var_represent = y_reconstructed
var_represent_original = y_label

# Configurar renderizadores como subplots
renderer_var.renderer.SetViewport(0.0, 0.0, 0.5, 1.0)  # Subplot izquierdo
renderer_label.renderer.SetViewport(0.5, 0.0, 1.0, 1.0)  # Subplot derecho

# Crear la paleta "cool to warm"
#custom_lut = create_custom_colormap()

# Asignar la paleta al mapper de ambos renderizadores
#renderer_var.mapper.SetLookupTable(custom_lut)
#renderer_label.mapper.SetLookupTable(custom_lut)

# Configurar fondo blanco
renderer_var.renderer.SetBackground(1, 1, 1)  # Fondo blanco
renderer_label.renderer.SetBackground(1, 1, 1)  # Fondo blanco

# Crear un actor de texto para var_represent
title_var = vtk.vtkTextActor()
title_var.SetInput("Var Represent")
title_varprop = title_var.GetTextProperty()
title_varprop.SetFontFamilyToArial()
title_varprop.SetFontSize(25)
title_varprop.SetColor(0, 0, 0)  # Color negro
title_var.SetPosition(300, 500)  # Ajustar posición manualmente según sea necesario
renderer_var.renderer.AddActor2D(title_var)

# Crear un actor de texto para label
title_label = vtk.vtkTextActor()
title_label.SetInput("Label")
title_labelprop = title_label.GetTextProperty()
title_labelprop.SetFontFamilyToArial()
title_labelprop.SetFontSize(25)
title_labelprop.SetColor(0, 0, 0)  # Color negro
title_label.SetPosition(300, 500)  # Ajustar posición manualmente según sea necesario
renderer_label.renderer.AddActor2D(title_label)

# Barras escala
scalar_bar_var = vtk.vtkScalarBarActor()
scalar_bar_var.SetLookupTable(renderer_var.mapper.GetLookupTable())
scalar_bar_var.GetLabelTextProperty().SetColor(0, 0, 0)  # Color de fuente negro
scalar_bar_var.GetLabelTextProperty().SetItalic(False)
scalar_bar_var.GetLabelTextProperty().SetShadow(False) 
scalar_bar_var.GetLabelTextProperty().SetFontFamilyToArial()
scalar_bar_var.GetLabelTextProperty().SetFontSize(15) 
scalar_bar_var.SetNumberOfLabels(5)

scalar_bar_label = vtk.vtkScalarBarActor()
scalar_bar_label.SetLookupTable(renderer_label.mapper.GetLookupTable())
scalar_bar_label.GetLabelTextProperty().SetColor(0, 0, 0)  # Color de fuente negro
scalar_bar_label.SetNumberOfLabels(5)

# Asignar las barras de escala
#scalar_bar_var.SetLookupTable(custom_lut)
#scalar_bar_label.SetLookupTable(custom_lut)

renderer_var.renderer.AddActor2D(scalar_bar_var)
renderer_label.renderer.AddActor2D(scalar_bar_label)

# Configurar la ventana de renderizado conjunta
render_window = vtk.vtkRenderWindow()
render_window.SetSize(1600, 600)  # Tamaño total de la ventana
render_window.AddRenderer(renderer_var.renderer)
render_window.AddRenderer(renderer_label.renderer)

# Configurar la cámara para ambos subplots
center = renderer_var.mesh.GetCenter()
for renderer in [renderer_var, renderer_label]:
    renderer.camera.SetPosition(center[0], center[1], center[2] + 35)  # Alejar la cámara
    renderer.camera.SetFocalPoint(center[0], center[1], center[2])  # Enfocar al centro
    renderer.camera.SetViewUp(1, 0, 0)  # Eje vertical hacia arriba
    renderer.camera.Elevation(270)  # Giro 180 grados sobre el eje horizontal
    renderer.camera.Azimuth(0)  # Rotar 0 grados en azimut
    renderer.renderer.ResetCameraClippingRange()

# Configurar el filtro para capturar imágenes
window_to_image_filter = vtk.vtkWindowToImageFilter()
window_to_image_filter.SetInput(render_window)

# Configurar video
output_video = os.path.join(output_directory, f"video23.avi")
sample_frame = os.path.join(output_directory, "sample_frame.png")
try:
    renderer.render_frame(var_represent[0, :], sample_frame)
except:
    renderer.render_frame(var_represent[:], sample_frame)

framei = cv2.imread(sample_frame)
height, width, layers = framei.shape
fps = 10  # Frames por segundo
fourcc = cv2.VideoWriter_fourcc(*'XVID')  # Codec para AVI
video = cv2.VideoWriter(output_video, fourcc, fps, (1600, 600))

# Iterar sobre instantes y generar frames
for instant in range(0, 1, 1):  # Cada 500 instantes
    try:
        vtk_scalars_var = numpy_to_vtk(var_represent[instant, :], deep=True)
    except:
        vtk_scalars_var = numpy_to_vtk(var_represent[:], deep=True)

    try:
        vtk_scalars_label = numpy_to_vtk(var_represent_original[instant, :], deep=True)
    except:
        vtk_scalars_label = numpy_to_vtk(var_represent_original[:], deep=True)

    renderer_var.mesh.GetPointData().SetScalars(vtk_scalars_var)
    renderer_label.mesh.GetPointData().SetScalars(vtk_scalars_label)

    renderer_var.mesh.Modified()
    renderer_label.mesh.Modified()

    # Renderizar la ventana con subplots
    render_window.Render()

    # Guardar la imagen como PNG
    window_to_image_filter.Modified()
    window_to_image_filter.Update()

    output_file = os.path.join(output_directory, f"frame_{instant:04d}.png")
    writer = vtk.vtkPNGWriter()
    writer.SetFileName(output_file)
    writer.SetInputData(window_to_image_filter.GetOutput())
    writer.Write()

    # Obtener la imagen como un array numpy
    image_data = window_to_image_filter.GetOutput()
    dims = image_data.GetDimensions()
    vtk_array = vtk.util.numpy_support.vtk_to_numpy(image_data.GetPointData().GetScalars())
    frame = vtk_array.reshape((dims[1], dims[0], 3))[::-1]  # Invertir eje Y

    # Escribir el frame en el video
    #video.write(frame)

    print(f"Frame guardado: {output_file}")
    #os.remove(output_file)

    plt.figure()
    plt.imshow(frame)
    plt.title(model_name)

    plt.tight_layout()
    plt.show()

    print(f"Frame guardado: {output_file}")
    print(model_name)

# Liberar el objeto VideoWriter
#video.release()
# Out:
# Frame guardado: /home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/output/renderized_heart/OMAMI_bs_200/frame_0000.png
# Frame guardado: /home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/output/renderized_heart/OMAMI_bs_200/frame_0000.png
# modelSimulation_01_200316_001_  4

# %%
max_val_value=np.max(y_label)
min_val_value=np.min(y_label)
# Crear renderizadores para var_represent y var_represent_original
renderer_var = EGMRenderer(faces, vertices, min_val=min_val_value, max_val=max_val_value)
try:
    renderer_label = EGMRenderer(faces, vertices,  min_val=min_val_value, max_val=max_val_value)
except:
    y_label = y_label[0][0]
    renderer_label = EGMRenderer(faces, vertices, min_val=min_val_value, max_val=max_val_value)

# Estándar y normalización de los datos (sin cambios)

estandarizar = False
normalizar = False

if estandarizar:
    y_label_std = np.zeros_like(y_label)
    for nodo in range(y_label.shape[1]): 
        mean_val = np.mean(y_label[:, nodo])  
        std_val = np.std(y_label[:, nodo])    
        if std_val != 0:  
            y_label_std[:, nodo] = (y_label[:, nodo] - mean_val) / std_val
        else:
            y_label_std[:, nodo] = 0  
    var_represent = y_reconstructed
    var_represent_original = y_label_std

if normalizar:
    y_label_n = np.zeros_like(y_label)
    for nodo in range(y_label.shape[1]):  
        min_val = np.min(y_label[:, nodo])
        max_val = np.max(y_label[:, nodo])
        
        if max_val != min_val:  
            y_label_n[:, nodo] = (y_label[:, nodo] - min_val) / (max_val - min_val)
        else:
            y_label_n[:, nodo] = 0  

    var_represent = y_reconstructed
    var_represent_original = y_label_n

var_represent = y_reconstructed
var_represent_original = y_label

# Configurar renderizadores como subplots
renderer_var.renderer.SetViewport(0.0, 0.0, 0.5, 1.0)  # Subplot izquierdo
renderer_label.renderer.SetViewport(0.5, 0.0, 1.0, 1.0)  # Subplot derecho

# Crear la paleta "cool to warm"
#custom_lut = create_custom_colormap()

# Asignar la paleta al mapper de ambos renderizadores
#renderer_var.mapper.SetLookupTable(custom_lut)
#renderer_label.mapper.SetLookupTable(custom_lut)

# Configurar fondo blanco
renderer_var.renderer.SetBackground(1, 1, 1)  # Fondo blanco
renderer_label.renderer.SetBackground(1, 1, 1)  # Fondo blanco

# Crear un actor de texto para var_represent
title_var = vtk.vtkTextActor()
title_var.SetInput("Var Represent")
title_varprop = title_var.GetTextProperty()
title_varprop.SetFontFamilyToArial()
title_varprop.SetFontSize(25)
title_varprop.SetColor(0, 0, 0)  # Color negro
title_var.SetPosition(300, 500)  # Ajustar posición manualmente según sea necesario
renderer_var.renderer.AddActor2D(title_var)

# Crear un actor de texto para label
title_label = vtk.vtkTextActor()
title_label.SetInput("Label")
title_labelprop = title_label.GetTextProperty()
title_labelprop.SetFontFamilyToArial()
title_labelprop.SetFontSize(25)
title_labelprop.SetColor(0, 0, 0)  # Color negro
title_label.SetPosition(300, 500)  # Ajustar posición manualmente según sea necesario
renderer_label.renderer.AddActor2D(title_label)

# Barras escala
scalar_bar_var = vtk.vtkScalarBarActor()
scalar_bar_var.SetLookupTable(renderer_var.mapper.GetLookupTable())
scalar_bar_var.GetLabelTextProperty().SetColor(0, 0, 0)  # Color de fuente negro
scalar_bar_var.GetLabelTextProperty().SetItalic(False)
scalar_bar_var.GetLabelTextProperty().SetShadow(False) 
scalar_bar_var.GetLabelTextProperty().SetFontFamilyToArial()
scalar_bar_var.GetLabelTextProperty().SetFontSize(15) 
scalar_bar_var.SetNumberOfLabels(5)

scalar_bar_label = vtk.vtkScalarBarActor()
scalar_bar_label.SetLookupTable(renderer_label.mapper.GetLookupTable())
scalar_bar_label.GetLabelTextProperty().SetColor(0, 0, 0)  # Color de fuente negro
scalar_bar_label.SetNumberOfLabels(5)

# Asignar las barras de escala
#scalar_bar_var.SetLookupTable(custom_lut)
#scalar_bar_label.SetLookupTable(custom_lut)

renderer_var.renderer.AddActor2D(scalar_bar_var)
renderer_label.renderer.AddActor2D(scalar_bar_label)

# Configurar la ventana de renderizado conjunta
render_window = vtk.vtkRenderWindow()
render_window.SetSize(1600, 600)  # Tamaño total de la ventana
render_window.AddRenderer(renderer_var.renderer)
render_window.AddRenderer(renderer_label.renderer)

# Configurar la cámara para ambos subplots
center = renderer_var.mesh.GetCenter()
for renderer in [renderer_var, renderer_label]:
    renderer.camera.SetPosition(center[0], center[1], center[2] + 35)  # Alejar la cámara
    renderer.camera.SetFocalPoint(center[0], center[1], center[2])  # Enfocar al centro
    renderer.camera.SetViewUp(1, 0, 0)  # Eje vertical hacia arriba
    renderer.camera.Elevation(30)  # Giro 180 grados sobre el eje horizontal
    renderer.camera.Azimuth(0)  # Rotar 0 grados en azimut
    renderer.renderer.ResetCameraClippingRange()

# Configurar el filtro para capturar imágenes
window_to_image_filter = vtk.vtkWindowToImageFilter()
window_to_image_filter.SetInput(render_window)

# Configurar video
output_video = os.path.join(output_directory, f"video23.avi")
sample_frame = os.path.join(output_directory, "sample_frame.png")
try:
    renderer.render_frame(var_represent[0, :], sample_frame)
except:
    renderer.render_frame(var_represent[:], sample_frame)

framei = cv2.imread(sample_frame)
height, width, layers = framei.shape
fps = 10  # Frames por segundo
fourcc = cv2.VideoWriter_fourcc(*'XVID')  # Codec para AVI
video = cv2.VideoWriter(output_video, fourcc, fps, (1600, 600))

# Iterar sobre instantes y generar frames
for instant in range(0, 1, 1):  # Cada 500 instantes
    try:
        vtk_scalars_var = numpy_to_vtk(var_represent[instant, :], deep=True)
    except:
        vtk_scalars_var = numpy_to_vtk(var_represent[:], deep=True)

    try:
        vtk_scalars_label = numpy_to_vtk(var_represent_original[instant, :], deep=True)
    except:
        vtk_scalars_label = numpy_to_vtk(var_represent_original[:], deep=True)

    renderer_var.mesh.GetPointData().SetScalars(vtk_scalars_var)
    renderer_label.mesh.GetPointData().SetScalars(vtk_scalars_label)

    renderer_var.mesh.Modified()
    renderer_label.mesh.Modified()

    # Renderizar la ventana con subplots
    render_window.Render()

    # Guardar la imagen como PNG
    window_to_image_filter.Modified()
    window_to_image_filter.Update()

    output_file = os.path.join(output_directory, f"frame_{instant:04d}.png")
    writer = vtk.vtkPNGWriter()
    writer.SetFileName(output_file)
    writer.SetInputData(window_to_image_filter.GetOutput())
    writer.Write()

    # Obtener la imagen como un array numpy
    image_data = window_to_image_filter.GetOutput()
    dims = image_data.GetDimensions()
    vtk_array = vtk.util.numpy_support.vtk_to_numpy(image_data.GetPointData().GetScalars())
    frame = vtk_array.reshape((dims[1], dims[0], 3))[::-1]  # Invertir eje Y

    # Escribir el frame en el video
    #video.write(frame)

    print(f"Frame guardado: {output_file}")
    #os.remove(output_file)

    plt.figure()
    plt.imshow(frame)
    plt.title(model_name)

    plt.tight_layout()
    plt.show()

    print(f"Frame guardado: {output_file}")
    print(model_name)

# Liberar el objeto VideoWriter
#video.release()

print(f"Video guardado en {output_video}")
# Out:
# Frame guardado: /home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/output/renderized_heart/OMAMI_bs_200/frame_0000.png
# Frame guardado: /home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/output/renderized_heart/OMAMI_bs_200/frame_0000.png
# modelSimulation_01_200316_001_  4
# Video guardado en /home/pdi/miriamgf/tesis/Autoencoders/code/egm_reconstruction/Code/output/renderized_heart/OMAMI_bs_200/video23.avi
