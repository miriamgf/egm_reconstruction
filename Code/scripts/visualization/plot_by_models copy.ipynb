# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../..", "Code")))
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
from tools_.tools import *
from vis_functions import *
# Out:
# 2024-08-30 11:22:34.774616: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-30 11:22:34.801472: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-30 11:22:34.801492: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-30 11:22:34.802344: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-30 11:22:34.808117: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-30 11:22:35.284001: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#CONFIGURATION

#experiment= '20240825-181432_EXP_0'
experiment = '20240827-112359_EXP_0'
model='modelSimulation_01_200212_001_  5'

# %%
tikhonov, fs_tk= load_signals('Tik')
dl, fs_dl= load_signals('DL', experiment=experiment)

# %%
loaded_models_dl =[]
for key in dl.keys():
    if key != '__header__' and  key != '__version__' and   key != '__globals__':
        loaded_models_dl.append(key)
loaded_models_tk =[]
for key in tikhonov.keys():
    if key != '__header__' and  key != '__version__' and   key != '__globals__':
        loaded_models_tk.append(key)

common_models = np.intersect1d(loaded_models_dl, loaded_models_dl)
model = common_models[0]


print('* Model loaded from selected DL experiment:', loaded_models_dl)
print('* Model loaded from selected Tikhonov experiment:',loaded_models_tk)
print(' --> Models that therefore can be evaluated:', common_models)
# Out:
# * Model loaded from selected DL experiment: ['modelSimulation_01_200212_001_  5', 'modelSimulation_01_200212_001_ 10', 'modelSimulation_01_200316_001_  3', 'modelSimulation_01_200316_001_  4', 'modelSimulation_01_200316_001_  8', 'modelSimulation_01_200428_001_004', 'modelSimulation_01_200428_001_008', 'modelSimulation_01_200428_001_010', 'modelSimulation_01_210119_001_001', 'modelSimulation_01_210208_001_002']
# * Model loaded from selected Tikhonov experiment: ['modelLA_LIPV_150119', 'modelLA_LSPV_150113', 'modelLA_LSPV_150203', 'modelLA_PLAW_140612', 'modelLA_PLAW_140711_arm', 'modelLA_RIPV_150121', 'modelLA_RSPV_150113', 'modelLA_RSPV_CAF_150115', 'modelRA_RAA_141216', 'modelRA_RAA_141230', 'modelRA_RAFW_140807', 'modelRA_RAFW_SAF_140730', 'modelSimulation_01_190502_001_003', 'modelSimulation_01_190502_001_004', 'modelSimulation_01_190502_001_005', 'modelSimulation_01_190502_001_006', 'modelSimulation_01_190619_001_001', 'modelSimulation_01_190619_001_002', 'modelSimulation_01_190619_001_003', 'modelSimulation_01_190619_001_004', 'modelSimulation_01_190717_001_001', 'modelSimulation_01_190717_001_002', 'modelSimulation_01_190717_001_003', 'modelSimulation_01_190717_001_004', 'modelSimulation_01_191001_001_001', 'modelSimulation_01_191001_001_002', 'modelSimulation_01_191001_001_005', 'modelSimulation_01_191001_001_007', 'modelSimulation_01_200212_001_  1', 'modelSimulation_01_200212_001_  2', 'modelSimulation_01_200212_001_  4', 'modelSimulation_01_200212_001_  5', 'modelSimulation_01_200212_001_  6', 'modelSimulation_01_200212_001_  7', 'modelSimulation_01_200212_001_  8', 'modelSimulation_01_200212_001_  9', 'modelSimulation_01_200212_001_ 10', 'modelSimulation_01_200316_001_  1', 'modelSimulation_01_200316_001_  2', 'modelSimulation_01_200316_001_  3', 'modelSimulation_01_200316_001_  4', 'modelSimulation_01_200316_001_  5', 'modelSimulation_01_200316_001_  6', 'modelSimulation_01_200316_001_  7', 'modelSimulation_01_200316_001_  8', 'modelSimulation_01_200316_001_  9', 'modelSimulation_01_200316_001_ 10', 'modelSimulation_01_200428_001_001', 'modelSimulation_01_200428_001_002', 'modelSimulation_01_200428_001_003', 'modelSimulation_01_200428_001_004', 'modelSimulation_01_200428_001_005', 'modelSimulation_01_200428_001_006', 'modelSimulation_01_200428_001_007', 'modelSimulation_01_200428_001_008', 'modelSimulation_01_200428_001_009', 'modelSimulation_01_200428_001_010', 'modelSimulation_01_201223_001_002', 'modelSimulation_01_210119_001_001', 'modelSimulation_01_210205_001_002', 'modelSimulation_01_210205_001_003', 'modelSimulation_01_210208_001_002', 'modelSimulation_01_210209_001_001', 'modelSimulation_01_210209_001_002', 'modelSimulation_01_210209_001_003', 'modelSimulation_01_210210_001_001', 'modelSinusal_150629', 'modelTwoRotors_181219']
#  --> Models that therefore can be evaluated: ['modelSimulation_01_200212_001_  5' 'modelSimulation_01_200212_001_ 10'
#  'modelSimulation_01_200316_001_  3' 'modelSimulation_01_200316_001_  4'
#  'modelSimulation_01_200316_001_  8' 'modelSimulation_01_200428_001_004'
#  'modelSimulation_01_200428_001_008' 'modelSimulation_01_200428_001_010'
#  'modelSimulation_01_210119_001_001' 'modelSimulation_01_210208_001_002']

# %% [markdown]
# Extract signals from dictionaries

# %%
dl_label=dl[model]['label'][0][0]
dl_signal=dl[model]['reconstruction'][0][0]
tikhonov_label=tikhonov[model]['label'][0][0]
tikhonov_signal=tikhonov[model]['reconstruction'][0][0]
print(dl_signal.shape, tikhonov_signal.shape)
# Out:
# (8000, 1366) (2001, 2048)

# %%
dl_signal.shape
# Out:
# (8000, 1366)

# %%
plt.figure()
plt.imshow(dl_signal[200:700, :], cmap= 'jet')
plt.show()

# %%
#Process tikhonov to match dl processing

if fs_dl < fs_tk:
    #Subsampling
    print('fs_dl:', fs_dl, 'and fs_tik:', fs_tk)
    tikhonov_signal = signal.resample_poly(tikhonov_signal, fs_dl, 500, axis=0)
    tikhonov_label = signal.resample_poly(tikhonov_label, fs_dl, 500, axis=0)
    print('Tik Shape:', tikhonov_signal.shape, '| DL shape:', dl_signal.shape )
# Out:
# fs_dl: 200 and fs_tik: 500
# Tik Shape: (801, 2048) | DL shape: (8000, 1366)

# %%
common_models
# Out:
# array(['modelSimulation_01_200212_001_  5',
#        'modelSimulation_01_200212_001_ 10',
#        'modelSimulation_01_200316_001_  3',
#        'modelSimulation_01_200316_001_  4',
#        'modelSimulation_01_200316_001_  8',
#        'modelSimulation_01_200428_001_004',
#        'modelSimulation_01_200428_001_008',
#        'modelSimulation_01_200428_001_010',
#        'modelSimulation_01_210119_001_001',
#        'modelSimulation_01_210208_001_002'], dtype='<U33')

# %%
print('Model', model)
plot_1D_signals(tikhonov_signal, tikhonov_label, dl_signal, dl_label,
                node = 10,
                torso = 0,
                n_samples= 5000,
                normalize_tik= True,
                filter_tik_label= False)
# Out:
# Model modelSimulation_01_200212_001_  5

# %%
plot_correlation_by_nodes(range_of_models=common_models, smoothing = 5, type_corr = 'Spearman', experiment=experiment)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plot_correlation_by_nodes(range_of_models=common_models, smoothing = 5, type_corr = 'Spearman', experiment=experiment)
#
# File ~/tesis/Autoencoders/code/egm_reconstruction/Code/scripts/visualization/vis_functions.py:161, in plot_correlation_by_nodes(range_of_models, smoothing, type_corr, experiment)
#     158 elif type_corr == 'Spearman':
#     160     corr_i_tk = corr_spearman_cols(tikhonov_signal, tikhonov_label)
# --> 161     corr_i_dl = corr_spearman_cols(dl_signal, dl_label)
#     163 if smoothing != None:
#     164     corr_i_tk = moving_average(corr_i_tk, window_size = smoothing)
#
# File ~/tesis/Autoencoders/code/egm_reconstruction/Code/tools_/tools.py:1364, in corr_spearman_cols(array1, array2)
#    1362 corr = np.zeros(n_cols)
#    1363 for i in range(n_cols):
# -> 1364     corr[i], _ = spearmanr(array1[:, i], array2[:, i])
#    1366 return corr
#
# File /home/profes/miriamgf/anaconda3/envs/research/lib/python3.10/site-packages/scipy/stats/_stats_py.py:5442, in spearmanr(a, b, axis, nan_policy, alternative)
#    5439 warn_msg = ("An input array is constant; the correlation coefficient "
#    5440             "is not defined.")
#    5441 if axisout == 0:
# -> 5442     if (a[:, 0][0] == a[:, 0]).all() or (a[:, 1][0] == a[:, 1]).all():
#    5443         # If an input is constant, the correlation coefficient
#    5444         # is not defined.
#    5445         warnings.warn(stats.ConstantInputWarning(warn_msg))
#    5446         res = SignificanceResult(np.nan, np.nan)
#
# File /home/profes/miriamgf/anaconda3/envs/research/lib/python3.10/site-packages/numpy/core/_methods.py:61, in _all(a, axis, dtype, out, keepdims, where)
#      58         return umr_any(a, axis, dtype, out, keepdims)
#      59     return umr_any(a, axis, dtype, out, keepdims, where=where)
# ---> 61 def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      62     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      63     if where is True:
#      64         return umr_all(a, axis, dtype, out, keepdims)
#
# KeyboardInterrupt:

# %%
plot_correlation_by_models(range_of_models=common_models, type_corr = 'Pearson', separation = 0.7, rotation=45, experiment = experiment)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plot_correlation_by_models(range_of_models=common_models, type_corr = 'Pearson', separation = 0.7, rotation=45, experiment = experiment)
#
# File ~/tesis/Autoencoders/code/egm_reconstruction/Code/scripts/visualization/vis_functions.py:217, in plot_correlation_by_models(range_of_models, type_corr, separation, rotation, experiment)
#     214 if type_corr == 'Pearson':
#     216     corr_i_tk = corr_pearson_cols(tikhonov_signal, tikhonov_label)
# --> 217     corr_i_dl = corr_pearson_cols(dl_signal, dl_label)
#     220 elif type_corr == 'Spearman':
#     222     corr_i_tk = corr_spearman_cols(tikhonov_signal, tikhonov_label)
#
# File ~/tesis/Autoencoders/code/egm_reconstruction/Code/tools_/tools.py:1337, in corr_pearson_cols(array1, array2)
#    1335 corr = np.zeros(n_cols)
#    1336 for i in range(n_cols):
# -> 1337     corr[i], _ = pearsonr(array1[:, i], array2[:, i])
#    1339 return corr
#
# File /home/profes/miriamgf/anaconda3/envs/research/lib/python3.10/site-packages/scipy/stats/_stats_py.py:4858, in pearsonr(x, y, alternative, method)
#    4855 # As explained in the docstring, the distribution of `r` under the null
#    4856 # hypothesis is the beta distribution on (-1, 1) with a = b = n/2 - 1.
#    4857 ab = n/2 - 1
# -> 4858 dist = stats.beta(ab, ab, loc=-1, scale=2)
#    4859 if alternative == 'two-sided':
#    4860     prob = 2*dist.sf(abs(r))
#
# File /home/profes/miriamgf/anaconda3/envs/research/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:849, in rv_generic.__call__(self, *args, **kwds)
#     848 def __call__(self, *args, **kwds):
# --> 849     return self.freeze(*args, **kwds)
#
# File /home/profes/miriamgf/anaconda3/envs/research/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:844, in rv_generic.freeze(self, *args, **kwds)
#     829 """Freeze the distribution for the given arguments.
#     830
#     831 Parameters
#    (...)
#     841
#     842 """
#     843 if isinstance(self, rv_continuous):
# --> 844     return rv_continuous_frozen(self, *args, **kwds)
#     845 else:
#     846     return rv_discrete_frozen(self, *args, **kwds)
#
# File /home/profes/miriamgf/anaconda3/envs/research/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:463, in rv_frozen.__init__(self, dist, *args, **kwds)
#     460 self.kwds = kwds
#     462 # create a new instance
# --> 463 self.dist = dist.__class__(**dist._updated_ctor_param())
#     465 shapes, _, _ = self.dist._parse_args(*args, **kwds)
#     466 self.a, self.b = self.dist._get_support(*shapes)
#
# File /home/profes/miriamgf/anaconda3/envs/research/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:1845, in rv_continuous.__init__(self, momtype, a, b, xtol, badvalue, name, longname, shapes, seed)
#    1843 else:
#    1844     dct = dict(distcont)
# -> 1845     self._construct_doc(docdict, dct.get(self.name))
#
# File /home/profes/miriamgf/anaconda3/envs/research/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:809, in rv_generic._construct_doc(self, docdict, shapes_vals)
#     807     self.__doc__ = self.__doc__.replace("%(shapes)s, ", "")
#     808 try:
# --> 809     self.__doc__ = doccer.docformat(self.__doc__, tempdict)
#     810 except TypeError as e:
#     811     raise Exception("Unable to construct docstring for "
#     812                     "distribution \"%s\": %s" %
#     813                     (self.name, repr(e))) from e
#
# File /home/profes/miriamgf/anaconda3/envs/research/lib/python3.10/site-packages/scipy/_lib/doccer.py:51, in docformat(docstring, docdict)
#      49 if not docdict:
#      50     return docstring
# ---> 51 lines = docstring.expandtabs().splitlines()
#      52 # Find the minimum indent of the main docstring, after first line
#      53 if len(lines) < 2:
#
# KeyboardInterrupt:
